# %%
import numpy as np
import json
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.optimizers import Adam

# %%
# -----------------------------------------
# 1. Training Data
# -----------------------------------------
questions = [
    "hi", "hello", "how are you", "what is your name",
    "bye", "thank you", "thanks"
]

answers = [
    "Hello! How can I help you?",
    "Hello! How can I help you?",
    "I am fine! How are you?",
    "I am your chatbot created using Deep Learning + FastAPI",
    "Goodbye! Have a nice day!",
    "You're welcome!",
    "You're welcome!"
]

# -----------------------------------------

# %%
# 2. Tokenization
# -----------------------------------------
tokenizer = Tokenizer()
tokenizer.fit_on_texts(questions + answers)

vocab_size = len(tokenizer.word_index) + 1

# %%
# Convert text → sequences
X = tokenizer.texts_to_sequences(questions)
y = tokenizer.texts_to_sequences(answers)

# %%
# Pad sequences
max_len = 10
X = pad_sequences(X, maxlen=max_len)
y = pad_sequences(y, maxlen=max_len)

y = np.array(y)

# %%
# -----------------------------------------
# 3. Build Model
# -----------------------------------------
model = Sequential()
model.add(Embedding(vocab_size, 64, input_length=max_len))
model.add(LSTM(64))
model.add(Dense(vocab_size, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy", optimizer=Adam(0.001))

# -----------------------------------------
# 4. Train
# -----------------------------------------

# %%
# -----------------------------------------
# 4. Train
# -----------------------------------------
y = np.expand_dims(y[:, 0], axis=-1)  # first token prediction

model.fit(X, y, epochs=50)
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 3.4424
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 3.4032
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 3.3626
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 3.3178
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 3.2661
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 3.2050
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 3.1316
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 3.0428
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 2.9344
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 2.8019
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 2.6398
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 2.4425
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 2.2057
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - loss: 1.9284
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - loss: 1.6172
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 1.2895
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.9735
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.6996
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 0.4870
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.3364
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.2353
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - loss: 0.1685
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.1239
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0934
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0720
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0565
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.0451
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0366
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 582ms/step - loss: 0.0301
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - loss: 0.0251
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 0.0213
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - loss: 0.0182
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - loss: 0.0157
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0137
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step - loss: 0.0121
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step - loss: 0.0108
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0097
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 0.0088
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 0.0080
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.0073
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0068
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0063
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0058
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0055
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0052
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0049
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0046
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0044
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0042
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.0041

# %%
# -----------------------------------------
# 5. Save Model + Tokenizer
# -----------------------------------------
model.save("model/chatbot_model.h5")

#with open("model/tokenizer.json", "w") as f:
  #  f.write(tokenizer.to_json())

with open("model/tokenizer.json") as f:
    tokenizer_data = json.load(f)

# Convert dict to JSON string
tokenizer_json = json.dumps(tokenizer_data)

#tokenizer = tokenizer_from_json(tokenizer_json)


print("Model training completed and saved!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model training completed and saved!
